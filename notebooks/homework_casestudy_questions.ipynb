# %% [markdown]
# # Easy Level (1–8)
#
# These questions introduce students to basic querying, counting, filtering, and simple aggregation.
#
# ---
#
# ## Question 1
#
# ### Question
#
# **What is the total number of sales transactions recorded in the dataset?**
#
# ### Business Objective
#
# Management wants to determine the total number of sales transactions recorded by the business. This metric provides an overall measure of business activity and serves as a baseline Key Performance Indicator (KPI) for subsequent analyses.
#
# ---
#
# ## Question 2
#
# ### Question
#
# **How many sales transactions were processed by each store location, and how do the transaction volumes compare across different store locations?**
#
# ### Business Objective
#
# Management wants to compare the number of sales transactions processed by each store location to identify stores with higher and lower customer activity. This information supports operational planning and resource allocation.
#
# ---
#
# ## Question 3
#
# ### Question
#
# **How many sales transactions were completed using each purchase method, and how do customers' purchasing preferences compare across different purchase methods?**
#
# ### Business Objective
#
# Management wants to understand customer purchasing preferences by comparing the number of transactions completed through different purchase methods, such as In-store, Online, and Phone.
#
# ---
#
# ## Question 4
#
# ### Question
#
# **How many sales transactions were completed using coupons, and how many were completed without coupons?**
#
# ### Business Objective
#
# Management wants to evaluate the adoption of promotional coupons by comparing the number of transactions where coupons were used versus those where they were not.
#
# ---
#
# ## Question 5
#
# ### Question
#
# **How many sales transactions were recorded in each year?**
#
# ### Business Objective
#
# Management wants to compare annual transaction volumes to understand how business activity has changed over time.
#
# ---
#
# ## Question 6
#
# ### Question
#
# **How many sales transactions were recorded in each month, and are there any seasonal variations in transaction volume?**
#
# ### Business Objective
#
# Management wants to identify seasonal patterns in customer purchases to support inventory planning and promotional campaigns.
#
# ---
#
# ## Question 7
#
# ### Question
#
# **Which products are available in the sales dataset?**
#
# ### Business Objective
#
# Management wants to identify the range of products sold by the business and understand the available product portfolio.
#
# ---
#
# ## Question 8
#
# ### Question
#
# **Which store locations are represented in the dataset?**
#
# ### Business Objective
#
# Management wants to identify the geographical locations where the business operates.
#
# ---
#
# # Medium Level (9–17)
#
# These questions introduce the MongoDB Aggregation Framework.
#
# ---
#
# ## Question 9
#
# ### Question
#
# **Which products have the highest total quantity sold across all sales transactions?**
#
# ### Business Objective
#
# Management wants to identify products with the highest customer demand based on the total quantity sold to improve inventory planning.
#
# ---
#
# ## Question 10
#
# ### Question
#
# **Which products generated the highest total sales revenue across all sales transactions?**
#
# ### Business Objective
#
# Management wants to identify products that contribute the most revenue to support pricing, procurement, and inventory decisions.
#
# ---
#
# ## Question 11
#
# ### Question
#
# **What is the average number of products purchased in a single sales transaction?**
#
# ### Business Objective
#
# Management wants to understand the typical purchase size of customers by calculating the average number of products included in each transaction.
#
# ---
#
# ## Question 12
#
# ### Question
#
# **What is the average quantity purchased for each product?**
#
# ### Business Objective
#
# Management wants to compare the average purchase quantity of products to understand customer purchasing behavior.
#
# ---
#
# ## Question 13
#
# ### Question
#
# **How many sales transactions were processed by each purchase method within every store location?**
#
# ### Business Objective
#
# Management wants to compare customer purchasing preferences across different store locations.
#
# ---
#
# ## Question 14
#
# ### Question
#
# **Which store locations generated the highest total sales revenue?**
#
# ### Business Objective
#
# Management wants to compare store performance based on total sales revenue rather than transaction count alone.
#
# ---
#
# ## Question 15
#
# ### Question
#
# **Which products recorded the highest total quantity sold in each store location?**
#
# ### Business Objective
#
# Management wants to understand product demand across different store locations to improve store-specific inventory planning.
#
# ---
#
# ## Question 16
#
# ### Question
#
# **How does coupon usage vary across different store locations?**
#
# ### Business Objective
#
# Management wants to compare coupon adoption across stores to evaluate the effectiveness of promotional campaigns in different regions.
#
# ---
#
# ## Question 17
#
# ### Question
#
# **What is the average customer satisfaction rating for each store location?**
#
# ### Business Objective
#
# Management wants to compare customer satisfaction levels across stores to identify locations delivering better customer experiences and those requiring service improvements.
#
# ---
#
# # Difficult Level (18–25)
#
# These require multi-stage aggregation, calculations, and business interpretation.
#
# ---
#
# ## Question 18
#
# ### Question
#
# **Which customers have spent the highest total amount across all their purchases?**
#
# ### Business Objective
#
# Management wants to identify high-value customers for loyalty programs, personalized marketing campaigns, and customer retention initiatives.
#
# ---
#
# ## Question 19
#
# ### Question
#
# **How has total sales revenue changed over time?**
#
# ### Business Objective
#
# Management wants to analyze revenue trends over time to identify periods of business growth or decline.
#
# ---
#
# ## Question 20
#
# ### Question
#
# **Which purchase method generated the highest total sales revenue?**
#
# ### Business Objective
#
# Management wants to compare the revenue generated by different purchase methods to identify the most valuable sales channels.
#
# ---
#
# ## Question 21
#
# ### Question
#
# **Which products generated the highest total sales revenue?**
#
# ### Business Objective
#
# Management wants to identify the products that contribute the highest revenue so that the business can prioritize inventory, procurement, and marketing efforts.
#
# ---
#
# ## Question 22
#
# ### Question
#
# **What is the average sales value of a transaction for each store location?**
#
# ### Business Objective
#
# Management wants to compare the average transaction value across different store locations to better understand customer spending behavior.
#
# ---
#
# ## Question 23
#
# ### Question
#
# **Which months generated the highest total sales revenue, and are there any seasonal revenue trends?**
#
# ### Business Objective
#
# Management wants to identify seasonal revenue patterns to improve inventory planning, staffing, and promotional activities.
#
# ---
#
# ## Question 24
#
# ### Question
#
# **Which products have the highest average selling price?**
#
# ### Business Objective
#
# Management wants to identify premium-priced products by comparing the average selling price of each product. This information supports pricing strategy and product portfolio analysis.
#
# ---
#
# ## Question 25
#
# ### Question
#
# **How does customer satisfaction vary across different purchase methods?**
#
# ### Business Objective
#
# Management wants to compare customer satisfaction across different purchase methods to evaluate whether certain purchasing channels provide a better customer experience and to identify opportunities for service improvement.
#
# ---
